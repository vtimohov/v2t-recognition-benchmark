# %% [markdown]
# EXPERIMENT EXPLANATION
#
# CONTEXT: We utilize a third-party service for voice-to-text transcription. The output of this process yields a set of texts. Subsequently, we employ these texts as context for our Question Answering solution. Therefore, it is imperative to ensure that the voice-to-text (V2T) service provides satisfactory text quality.
#
# GOAL: a benchmark enabling the estimation of text quality.
#
# HOW TO: Let us assume that satisfactory text content consists solely of English words, along with some names, toponyms, etc. So we can use next equation:
# $$
# \begin{equation*}
# s=\ \frac{t_{b}}{t_{g}} \ *\ 100\%
# \end{equation*}
# $$
# Where $t_{g}$ is a total number of words is a text dictinary. And $t_{m}$ is bad tokens in this dictinary.

# %% [markdown]
# EXTRACT TEXT FROM THE FILES

# %%
import configparser
import os

config = configparser.ConfigParser()
config.read('config.ini')
folder_path = config['Paths']['folder_path']

# Function to merge content of multiple .txt files into a single string
def merge_txt_files(folder_path):
    file_paths = os.listdir(folder_path)
    merged_text = ""
    for file_path in file_paths:
        # Open each file and read its content
        with open(file_path, 'r') as file:
            text = file.read()
        # Append the content to the merged_text variable
        merged_text += text + "\n"  # Optionally, you can add a newline character after each document
    return merged_text

# Call the function to merge the .txt files
merged_text = merge_txt_files(folder_path)

# Display the merged text
print(merged_text)
# Out:
# To access your star reports, you will click on the reports tile on your Renaissance home page and then star assessment. If you have a report that you use often, you can click the thumb tack inside that report tile to move the report to the top of your screen. If you are viewing a report and would like more information about that report. Clicking on the question mark at the top of your screen will bring up an article from Renaissance that explains that report in detail.
# The star diagnostic report presents diagnostic and skill information for an individual student. You will find this under the state performance and mastery section of your reports page. When choosing your reports parameters, there are two things you want to keep in mind always select the benchmark type of state when it is available and always uncheck the show grade equivalent box as that can be confusing for students and parents. This report has a color coded bar that will show you where your student is performing. The report will also show you your students scaled score. The scaled score is calculated based on the difficulty of questions and the number of correct responses because the same range is used for all students. Scaled scores can be used to compare student performance across grade levels. All norm reference scores are derived from the skilled score. The percentile rank shows you where your students scored compared to other students that took the test in the same grade around the same time. The instructional reading level is calculated after a student completes a star reading test. It is a criterion reference score that is the highest reading level at which a student is 80% proficient or higher at comprehending material with assistance. Research has found that this level of comprehension corresponds to being at least 90 to 98% proficient at recognizing words. Star reading does not directly assess word recognition and instructional reading levels are pre primer primer grades one through 12.9 and post high school. The diagnostic test also shows domain scores. It'll show you the percent of mastery on skills within each domain in the student's grade level. You can also see the zone of proximal development which is their reading level and it has a link to a book finder where they can search for books that are appropriate for them in their ZPD. You can also see their test duration and fidelity located in this report.
# Today, we will be discussing the basics of giving a star assessment with fidelity set clear testing expectations with your students and families. Before testing begins, it is important to give the a test in a quiet distraction, free environment. If distractions arise during the testing session, stop the test and reschedule for another day. Teachers should actively monitor their students while testing to ensure they are progressing appropriately through the test. The star tests are adaptive so it is important to make sure that the students are not receiving help as it will skew the data and potentially make the next test too hard. Calculators will be provided on screen for select algebra and geometry questions when necessary. All other questions are designed to be answered without a calculator outside calculators should not be used unless there is a specific IEP or 504 accommodation epic. Students will log in by clicking on the Renaissance icon on their clever dashboard. On the Renaissance homepage. Students can access star reading star math, early literacy and CBM. Before the test begins, students will see a series of practice questions. It is important to monitor the students during this time to ensure they make it past the practice questions and on to the actual test to pause or stop the test. You will click the stop test button in the upper right corner of the screen from there. A pop up menu will appear asking what would you like to do with the options? Resume later? Stop test or cancel resume later will allow you to pause the test. If you choose to resume the test on a later date, you must do so within eight days, stop test will cancel the test session and erase all the testing data from that session. This action cannot be undone. Cancel, simply closes the menu. Please note for the resume later and stop test options. You will need to enter your monitor password after the student has completed the final question, they will see this screen letting them know that they have completed the test. Be sure the student clicks ok. To log out. If you have any questions, please submit a ticket to instructional assessments and we will be happy to help.
# The instructional planning student report provides a list of recommended skills for individualized instructions based on the most recent student activity. The instructional planning class report does this for classes or groups of students? Please note the instructional planning report only shows data from the most recent test. So if you want to compare from test test, you will need to download and save that report. This report can be found in the screening and instructional planning section of the reports page. Remember to always change the benchmark type to state whenever it is available, you can also choose to show only the focus skills. If you find that useful. The top portion of this report looks much like the diagnostic report. It shows what category your student is performing in the scaled score and percentile rate. The bottom of this report will show suggested skills for your student. Please note that this report was designed for national standards. So while it does show Oklahoma standards, it tries to match them with the national standards and sometimes that can cause discrepancies.
# Hello and welcome to the 2023 2024 Epic Learning Community benchmark course. In this course, you will learn more about how we benchmark here at Epic and some of the changes from past years you will see linked in the course. The benchmark schedule for 2324. This schedule has three required benchmark windows. It also allows for 1/4 optional benchmark window for students still needing to show growth. Also, for this year, we wanted to give back more instruction time to teachers. So it was decided not to require high school ac T benchmarks. They will still be available in school at your home room for practice but not required for benchmarks. We will use star as we have the past three years while it is only required to give the star benchmark three times, we recommend Renaissance's best practice of progress monitoring every month, you will learn more about the star test in the coming videos and the star CBM requirements for students information can also be found on the benchmarks schedule. The tabs at the bottom are for CBM and O APP requirements. If you have questions, you can refer to your principal or submit a fresh service ticket to instructional assessments. We're always willing to help. Let's make this an epic year.
# Good morning. Good morning. Good morning. I'm super excited that you're here. We will get started in about 15 minutes here. Um If you wanna go ahead and join the airpod lesson, you should see the code on the screen. I'll also drop the link on the chat, whichever is easiest for you in this life, just like good morning. Good morning. If you are just joining, I'm happy that you're here. We're gonna get started in about 15 minutes. Um You can go ahead and join the live lesson at um join air pod dot com. The code is on the screen. I'll also drop the link in the chat whichever is easiest for you. Good morning. Good morning. If you're just joining, I'm super excited and ready that you're here. Um If you wanna go ahead and join the live lesson today, um You can go to join dot near pod dot com. I will also drop the link in the chat, whichever is easiest for you. We're gonna get started in about 12 minutes and feel free to go ahead and do that first activity. Um While we wait to get started, it's a pretty fun one. Um Hi Deborah. Um, can you go ahead and type your question in the chat? I can see that you have your hand raised. Good morning. Good morning. Good morning everyone. If you are just joining, you can go ahead and click on our live lesson. I'm gonna drop that link on the chat or you can type the code that's listed on the screen. We're gonna get started in about 10 minutes. David. Good morning, good morning. Um I'm happy that you are here. You can go ahead and join our live lesson today with the code on the screen or you can click the link in the chat, whichever works best for you while we are waiting. Please feel free to go ahead and do that activity that is on your live lesson. It's a fun one. a little bit of a challenging one, but you can go ahead and work on that while we're waiting here. We're gonna get started in about 10 minutes. That's no problem at all. Julie, you're here with us and I appreciate that you will still be able to definitely gain something from our session today. No worries at all. Yes, welcome, welcome, welcome. Um You can go ahead and click on that live lesson link that's in the chat or you can join our dear pod using the code that is on my screen. We will begin in about five minutes public. Mm Hello. Hello. I can see a few more people joined us. I'm happy that you are here. You can go ahead and join our live lesson with the code that's on the screen. Or can you can use the link that's in the chat, whichever is easiest for you and you can go ahead and get started on that intro activity while we are waiting to start. Good morning, Tiffany. Good morning. Good morning. Yes. One second, Cassandra. I see your message. All right. Uh It should be there for you. Now, Cassandra, let me know if you're able to turn it on, on your screen. No problem, no problem at all. Um Your mic is already off Catherine. No worries. You do not have to do a thing. Good morning and welcome. Welcome. If you wanna go ahead and join our live lesson today, you can use the code on your screen or you can also click the link in the chat, whichever is easiest for you. Um Kathy, you will actually get a recording of this training at the end of our session. Um But sure if you'd like to do it again, but there will be a recording sent out to you through email. Good morning to those of you that just hopped in. I'm happy that you are here. We're gonna get started in about 2 to 3 minutes. I would love for you to really participate in today's lesson by joining our live session with the code on the screen or using the link in the chat. Sometimes the link can be the easiest thing, but whatever works for you. And I would love for you guys to participate in that awesome open activity that's already on your live lesson. Um I think it's really fun and it's just really great way to kick off the morning. The live lesson link is in the chat or you can use the code that's on the screen and go to join dot airpod dot com, whichever way is more convenient for you a ...
# Due to testing security measures within Renaissance. There may be instances where a student's testing data is lost. We are going to cover those issues in this video to help you avoid that scenario with your students. The most common issue we see is having renaissance open in multiple windows or logged in on multiple devices. Make sure your student is completely signed out everywhere. Before beginning a star test, please advise your students not to use the browser's back or refresh buttons during a this will cause data to stop recording. If you're testing more than one student on the same device, it is important to not only log them completely out of clever but also to completely log them out of the device before testing, the next student resume a pause test from the same window. So if your student needs to take a restroom break, make sure when they come back that they are using the same window they started in and not completely opening a new test for longer breaks. After you pause the test, completely close out of Renaissance to start the test at a later time. The record book is a great place to look to ensure you haven't lost any data and to check for warnings, it is best practiced to frequently check your record book during a benchmark window to check for warnings and scores that were not recorded correctly. You may on occasion see a warning symbol that indicates a problem with one of your students tests. You will need to hover over the symbol to see more information. If you see one of the following symbols, further action may be required. It is best practice to administer any tests that had a short test time error. Again, this will not overwrite the benchmark score but will provide more accurate RT I data. Please make sure to closely monitor the student to ensure they are taking their time. Please note that the triangle error may mean one of two things. It may either mean that you have a probable non reader or that the practice test was not passed. If the practice test was not passed, the student will need to try again as the test was not completed.
# All right, good morning, everyone. Sorry about that. I was just setting up. Thank you for being here super early today. I'm super excited to be your facilitator. My name is Antonella and my colleague Liz is here joining us because we have a big crowd today. So she's gonna be helping out with the chat. I know that we have about seven minutes before we get started here. Um But I do want to make sure that you are set up for success in today's uh webinar today's learning. So a couple of announcements and by the way, I'm going to be repeating myself pretty frequently as more participants come in. So if you're feeling like, wow, now you've already said that five times. I am just trying to uh make sure that as people join, they are up to date with our direction. So forgive me if I sound like a broken record for a little bit of time. So first and foremost, uh this webinar is being recorded, we are recording right now. Um That is for you to have access to all the information uh for you to go ahead and watch at your own pace. And at your own time, another part is that you are in webinar mode, meaning that your cameras are turned off and you are muted. So the best way to communicate with us today is through the chat. Now, I was told that we have registration numbers um for like 100 participants today. So just be mindful. There's one of me and many of you. So Liz is going to be doing her best to focus on the chat, answer those questions and I can focus on the presentation. But of course, I'll always be monitoring that naturally and make sure that I also answer your questions as well. Um If you haven't done so already, go ahead and please log in to the near pod lesson to do that. You simply click the link that's on the chat. It's gonna directly take you there. Epic Charter teachers log in using Clever. So you can log in through clever or you can join as a guest that is up to you. So if you haven't done so already, please go ahead and join the near pad lesson and we're gonna get started in five minutes so far. I have 12 people joining um the lesson, Amanda Amy, Andrea, Bethany, Karina Jessica Kaylyn Christa Laurie, Robert Shari Susan Valerie. Thank you so much. Sorry, I see that you have your hand raised. Do you mind sharing your question in the chat, please? I see more folks are joining us. Welcome. We're gonna get started in about four minutes. My name is Antonella. I'll be your facilitator today if you haven't done so already before we get started, please join the near pod lesson by clicking the link that you see on the chat. That's the fastest way to join. Oh, wow, the chat is disabled, Liz, you had an answer to this. I meant to check this out if you can come off mute and, and share what the solution here is. That'd be wonderful. It is in my settings. OK? I'm sorry about that folks. I've never had that. I think there has been an update and I was not aware. We have three minutes uh before we get started. So let me try to quickly figure that out if you haven't done. So please join the near pod lesson in list. Can you please continue to add that link as more people join since the chat link does not save? Ok. All right. So I have updated my settings here. We should be able to uh now access the chat. If anyone wants to try, that would be great. We're gonna get started in just a minute. Hopefully in time with everything with Zoom figured out here. Welcome everyone. All right, we're gonna get started in just one minute here if you haven't done. So please um go ahead and log in to the NE PIN. If anyone can try to chat in something, I went ahead and changed my setting. I don't know if it automatically, uh, updated it on the current, uh zoom that we're in right now. All righty. So it is officially start time here. Um Half past the hour. It is 930 Eastern time. So I'm gonna go ahead and get us started here. I do not have the chat. All right. So, still disabled. All righty. So let me turn off my music here and let's problem solve. All right. So fir ...
# Hello, greetings, friends. Welcome, welcome. We will get started here in about a minute. But if you looks like we've got a lot of you here. This is exciting joining us in the near pod lesson at join dot near pod dot com. Using that code you see on the screen, I'm gonna pop this away, but it is also available over here and always at the top of the screen as well. So welcome, welcome. I'm so glad you're all enjoying uh all of these excellent meer pod sessions to uh this week. Um with me, I've got my friends, Liz and Ashley who will be manning the chat. So don't hesitate to ask any questions. Welcome, everyone. Um I'm so glad you've joined me today. We do have a great group and the question of the day or of this session being science, teaching science. What gets you excited about teaching science? And I see some great answers here, Angie when they're learning science, watching the kids seeing those experiences, Jamie loves teaching about plants. Personally, I am a gardener. I love everything to do with plants. So love seeing that as well. Following rabbit trails and engaging learning. I think that's one of those great things about science in general is that it's one of the core subjects that allows us to really dive in deeply into some really great learning, doing experiments that experiential learning. And so again, don't hesitate to ask your questions in the chat. We've got Liz and Ashley and uh let's get into it. We are going to be talking about supporting science with me pod. And really the thing that we're building here is that inquiry based learning, really diving into those essential questions with the really high quality. And actually let me see the link going in there in the chat a little bit. I'll go ahead and pop that link in there for everybody once again and we do have it on the screen there as well. My name is Ron Carroll. I'm one of the district strategy consultants here with Near Pod and thrilled that you've uh joined us this week for a lot of learning around the ways that we can use near pod. Hopefully, this will expand upon some of the uh learning you've already done. And if you're new, that's great too. I am here to help and I've got Liz and Ashley with me as well. So through this session, what we're going to be doing is looking at how we can use live like we're using right now where you've joined in and I'm controlling the experience as well as student paced near pod lessons to engage our students in science content. And there's a lot of rich science content available in the library. We'll look at some of that but really looking at those features and activities that we can turn on to engage our students to really complement that inquiry based learning and dive deeply into the heart of, of science. So with that, I want to point out a feature that I'm sure you guys have seen. But if you haven't yet, um what I've got going on my screen is we will be doing a little bit of back and forth. So I'll be demoing some things giving you a little time to play around. So ways that you can deal do that like I have here, I can pop between various tabs or you can always grab a tab there at the top and kind of click and hold and move it around to resize it like I've got over here or I've got other windows that I'm watching so that I can see and interact in a variety of ways. So whatever workflow works best for you is the one that works best for you. And I highly recommend that you use whatever works best for you, whether it's flipping around or you know, organizing your screen. But whatever you do, I do recommend that up here in the corner, there's a little pen and paper icon and if you click that open, you'll have the option to choose where to save these notes. And what this notes feature in your pod is, is it allows you to have all of the resources that we go through today sent to you either in your email through Google Drive or onedrive. I like to do the Google Drive stuff. So that sends me over here where I'm going to click ...
# All right. Hello and welcome everybody. So excited to have you all here today. My name is Jess Georgio and I am one of the district strategy consultants here on the near pod professional services team. I am joined by two of my amazing colleagues, Ashley and Liz. They are going to be help supporting this session by answering any and all of your questions in the Zoom chat box. So we're gonna go ahead and officially get things started in just about one more minute in order to fully participate in this lesson. I am going to ask that you join me by entering the link or the code. If you've never joined a near pod lesson before, please go to either join dot near pod dot com or just our regular near pod homepage at www dot near pod dot com. You can even log into your near pod accounts if you know how to do that and you'll enter this code in the red box. The code for today's lesson is Rzkau. So wherever you see that box that says join a lesson, it's read on our home page. It'll be a small text box. If you go to join dot near pod dot com or go to your account wherever you see that indication to join a lesson, please enter that code. I've also put the link to the lesson in the Zoom chat box. So if you prefer to use that, you can absolutely do that too. That has been reposted a couple of times. So you can choose to click on the link instead of use the code. It's either or either the link or the code will get you connected to the near pod lesson and will allow you to participate in all of the slides and activities that we have today. This near pod lesson is fo focused specifically on math content. So we're gonna be going through some activities and showing you how you can really engage your students in math instruction by utilizing all of the different activities and content that we have in the near pod platform. So I do highly recommend that you join in and participate in the lesson. It's going to be the best way for you to participate, follow along and really get the sense of how near pod can look sound and feel for your students. When completing math instruction, we'll give everybody another minute or two to make sure that you are connected. I feel that some people are still joining us through Zoom, which is correct. So if you've just joined us in the Zoom webinar, welcome. Remember this is a Zoom webinar. So cameras and microphones are automatically disabled. I will be actually turning off my camera in a few minutes. So we can all just focus on the content itself. So with those cameras and microphones turned off, the best way to communicate with us is through the chat box. That chat box is where you can post any and all of your questions. So I see a couple of folks raising hands. Unfortunately, we can't unmute you and this is a pretty large group. So keep that in mind. If you have questions as we go, please utilize that Zoom chat box in order to be able to participate. All right, now, Liz and Ashley are going to be answering your questions as we go and at the end, we'll stop for some Q and A. We'll make sure to cover all of the questions that you have at the very end of today's session. Now, I just wanna make sure that the chat box is working correctly. I'm seeing a lot of people raising their hand and that's giving me maybe an indication that it's not working correctly. It's up on my end and I have the ability to chat everyone. So I am wondering, here we go. I think I've ch hold on one minute. I think I just adjusted this. OK. Try that. All right. Woohoo, we got it to work. All right. I thought I had adjusted my setting before this. We've had some issues with the zoom chat lately with the newest update. But there we go. I was able to do it on the fly. So we are rocking now. Thanks everybody for indicating that it wasn't working by raising your hand. And now you can in fact use the chat to be able to post your questions as we go. So I'm gonna give it one more minute since I know a couple of us were held up on that small chat setting th ...
# Hello, Epic Charter Schools. My name is Erica. I'm really excited that you're joining me today. I know a bunch of my team members have been working with you. They've had amazing things to say about participation. So I am super psyched to be here and I want to start by asking everyone to join me in the live and interactive lesson. I know we haven't started quite yet and I'm gonna post this in multiple times, but I want to give everyone a little warm up. Um get excited, get, get in there. Hello Lisa Oden. Nice to meet you. And I'm also going to um set up some of my accessibility features including our live live transcript. I'm going to enable that. Fantastic. I see people coming in and I'll make sure everyone is able to join and also Hi Liz Pierce. I am also going to be sharing my screen now. Zoom is gonna do that thing where it takes over your entire screen. Yes, you're going to want to exit out and use uh oh Li Lisa, thank you for reminding me the chat box is disabled. We are having one day one heck of a time with Zoom. Um So absolutely, the chat box is disabled. That does not mean you can't reach out to me on the Q and A box. So let me share my screen. It overtook years. I'm so sorry if you're just joining us right now. That's fantastic. Um It's never too late and it's always, you're right on time to join us in the live and interactive lesson. So once you're in the live and interactive lesson, you're going to get the screen that I'm projecting right now. And the question to start you off today is what is your role in the school district? I wanna get to know you a little bit. And what makes English language, arts instruction unique if you need any inspiration or you finish early, I have embedded an article um to stretch your thinking a little bit. It's a PDF. Very cool. OK. Awesome. So I did see someone just raise their hand um instead of uh unmuted, we're going to ask our questions in the zoom Q and A box. I've got my, I, I actually have two screens one so I can keep my eyes glued to that Q and A box. Um and the other to be sharing my screen with you. So if you just joined us, perfect, you're on time. It's 331 and I'm ready to go. I hope you are too. My name is Erica Kepler. I am what's called the district strategy consultant. With Near Pod and I am super thrilled to be here today to present to you about how Near Pod works amazingly well with fan, with, with best practices in English language, arts pedagogy. Um I, my background is with English language learners and I taught six through 12. Obviously, we had a huge focus on El A. Um And so really diving into that pedagogy is something I'm super excited to do. Um So I love that, Becky is starting to answer that question. So in the moment, but build on the past, that's so interesting. I loved El A as well because sometimes you get really um you sparked just amazing conversations and can really get personal with students. To me, that was one of the, the things that got really unique. Um It's hard to just get personal, so personal in math. Now I'm seeing people raise their hand if you wouldn't mind asking me your question in the Q and A box that would be very helpful. The chat box is disabled, that's a zoom issue. But to join our live and interactive lesson, all you need to do is click the link in that zoom right now. I'm seeing 48 participants which is awesome. I love big groups. I am going to keep pasting that link to join the live and interactive lesson. This is for El A content, this is for language, arts content. That was a question I just got Yeah, sorry. It is for social studies content. Yep. Give me just a second. I think I've made a little mistake here using one of my colleagues. Yep. So what I'm going to ask you to do right now is give me just a second. What I'm gonna ask you to do is actually um shift to English language, arts instruction. I apologize for the mistake here. I am. I am going to get us back on track though. Now, if you are new to the um to the board here,  ...
# The star parent report provides a principal informational letter for parents or guardians and is available in English and Spanish in your report parameters. Make sure you always uncheck show great equivalent in any reports you share with parents. This particular report can be a little tricky as it is one of the only reports that has a horizontal scroll bar along the bottom. If you find that you're in this report and you can't get the apply button to turn blue and clickable. Make sure that you have scrolled all the way to the right. Until you see your students. The parent report is designed as a letter from teacher to parents or guardians. It gives a brief description of what the star test is shows where the student falls below average average or above average. It gives the scaled score percentile rank, instructional reading level and zone of proximal development. Along with the description of each the descriptions of each part of the score. Make this very useful to share with parents on a student's Renaissance home page. There is an option for parents to get email updates. If they click the get email updates icon, they can input their information and will receive an email anytime their student takes a star tip.
# Welcome everyone. Today we're diving into Star CBM Test administration and this training video will explore the RS A requirements with this assessment and equip you with the knowledge and skills to conduct it effectively. There are a few things that have changed from last year. So whether you are familiar with CBM or just getting started, this video will provide you with valuable insights and practical tips to ensure a seamless test administration process. Star CBM or curriculum based measurement is a series of short 60 to 92nd assessments designed to help the teacher accurately assess students readings so that you can better target instruction and intervention to the learner specific needs. Star CBM is a dyslexia screener that helps us stay in compliance with RS A laws. It is only intended to identify risks for characteristics of dyslexia. It is not intended to provide a diagnosis. Teachers will be giving these assessments one on one so that you can personally observe and document any patterns of growth or struggle for your student. First through third grade, students are required to take Star CBM in the fall if the percentile rank on their star or early literacy test falls at or below the 39th percentile. Kindergarten students will be required to take star CBM assessments after the winter benchmark. If their early literacy test falls at or below the 39th percentile, there are no exceptions for students with an IEP or 504 for O A students. You may reach out to the RT I team for guidance to be in compliance with RS A law. We have a strict timeline to follow when administering Star CBM for qualifying first through third grade students, star CBM must be given within the benchmark window. Students that come to us after the benchmark window has closed must take their CBM within 10 days of the I LP. If the I LP was done before November 1st, they must take the star test and then CBM. If they qualify before November 1st, students that come to us after November 1st will still be required to take both tests. And if they qualify Star CBM for progress monitoring purposes, the star reading benchmarks must be given before Star CBM can be administered. It is best practice to give the Star CBM immediately after star benchmarking. If the student scored in the 39th percentile or below in the event that your star scores are not immediately available. So the Star CBM must be given within the benchmark window. While there are multiple measures available in CBM to assess there is a required pathway that must be followed for RS a compliance kindergarten students will only benchmark in the fall window. They will not take CBM. First grade students will take star early literacy. And if their score is below the 40th percentile, you will then administer CBM expressive nonsense words and rapid automatic color naming for 2nd and 3rd grade students. You will start with star reading. If their star reading score falls below the 40th percentile, you then must administer star early literacy. If their star early literacy score falls below the 40th percentile, then you will administer the CBM assessments, expressive nonsense words and rapid automatic color naming. Kindergarten students will take the CBM in the winter window. If they qualify to allow time for instruction before screening, they will take star early literacy. And if their score falls below the 40th percentile, they will then take rapid automatic color naming only. Please note that even if you choose to give kindergarten students the CBM in the fall for RS A compliance, it still has to be given in the winter window. This is all that is required if the student needs to take any other CBM assessments, the RT I team will reach out to you. There are three ways to administer the test completely online, completely offline with the print version or with the teacher online and the student offline, the online or mixed versions are preferred due to the ability to record audio. Make sure you click the record a ...
# The state standards mastery class report shows you the level of mastery that students in a class have achieved in relation to the state standard. It also gives a prediction of what students mastery levels will be at the end of the school year. It is important to note that this report only shows data from the most recent test. So if you want to compare from test to test, you will need to download and save the report. You find this report under state performance and mastery on the reports page. The parameters for this report are pretty simple, select your school, your star 360 class and your subject, either reading or math and click update report on the next screen. All of your students will be grouped by grade level at the top of the screen. You have the option to on end of school year projected mastery and that projected mastery will come up in a circle next to their current mastery levels to get an individualized student report that you can share with parents. Click on a student's name. This will pull up a principal PDF version of the report that you can share with parents and use for planning.
# The star student progress monitoring report graphs, an individual students progress towards star goals. There are two parts to this report. One is the graph where it plots out your student's test scores and shows a trend line. The star at the end of the goal line represents the student's current goal. And the yellow dotted line can identify the start date of an intervention program if entered into star. The second part of this report shows that same information entered into a data table. It shows the date the goal was started, the various test dates that it was given your scaled score, percentile rank S GP and growth rate.
# This is a presentation on the Reading Sufficiency Act. And so the first thing that we wanna know is your current knowledge of Rs A. We know we have a lot of new teachers, we have teachers who have experience in different grade levels um or are coming from out of state. And so we wanna know how much you know about the law. Um even our experts um have something to learn today. So, um the state department is always updating guidance and that's, this is our opportunity to provide that to you. So, um we, we just like to kind of get a gauge on where teachers are coming from. Ok. So we start out my, this is uh the reading, uh the RS A team, we had a title change. So we've been reading specialists, we've been instructional coaches. Um but we are really focusing in on Rs A this year. And so, uh we had the title change to hopefully help clarify our role a little bit because we don't really hold a traditional reading specialist role here at Epic. We don't serve students, we don't provide interventions. And so, so we've changed to Rs A uh specialists and I'm the compliance coordinator. So um if you see any of us or speak to any of us, we can all help you with RS A. We do work um data and information in MD I team assignments. And so you can see here this is available on our epic one page, so teachers and administrators can refer back to it later. Um But the person assigned to the MD I team is really the point person. They are the most familiar with the information, the most familiar with who the teachers and principals are. And so they're the easiest point of contact, but any of us will communicate with anybody at any time. And when we um answer fresh service T tickets, that's a rotating schedule. So it could be anybody answering those tickets. But this can help if teachers don't know who they need to contact. This is a helpful starting point. Ok. So we'll jump into what is Rs A law. So Rs A law is the Reading Sufficiency Act. Um It's Oklahoma State law that says that students should be reading at grade level by the end of third grade. The focus is on um early identification, an intervention. So that's why we'll learn later. This covers kindergarten through third grade mostly. And so we're hoping to identify deficits as early as kindergarten, provide appropriate support and hopefully by the end of third grade, they're reading on grade level, um we say jokingly Rs A not to be confused with RT I because that is a consistent confusion um on for both of us, like we are constantly getting RT I questions, they're constantly getting RS A questions and we know it's confusing because there's a lot of overlap. Um The way that we hope to kind of make it a little clearer is RS A is like the umbrella where the law we govern every thing and then RT I is the framework for how we meet those requirements. And so it works together, but we're really compliance focussed. We are, here's what the law says, here's what we have to do to meet the law and making sure it's getting done. RT I has more implementation and more what? Oh I don't wanna. OK. Um RT I is more of the implementation and once they get the data, what do we do with it, how do we meet the need? And so hopefully that helps kind of clarify those roles. We anybody is welcome to reach out to any of us. It just might take a little longer to get questions answered if we have to redirect that. So we're hoping to help clarify that a little bit through the year. So we've included these checkpoints in the near pod to help with engagement and help teachers check understanding. And so um the Reading Sufficiency Act is an Oklahoma State blank. That state students must read on grade level by the end of blank grade. So if you want to participate and you wanna drag and drop your answers, you can go ahead, go ahead and do that and I'll give you a second to do that. Um So the Reading Sufficiency Act is an Oklahoma state law that state students must read on grade level by the end of the third grade. And just so, you ...
# It is important after testing to verify that the student completed the test and a score is showing while star scores can take up to 48 hours to populate into all reports. The first place they will appear is the record book report. We recommend checking this report to verify that the test was completed. To view star scores. The teacher must log in to the renaissance platform via clever. The teacher will then click the test that was given under the assess students menu. You can also get to the record book through the reports menu. After clicking on your desired test, choose record book from the drop down menu, click on the settings gear at the top right hand side of the screen to open the benchmarks menu on the benchmarks menu, choose state benchmark for math and reading and district benchmark for early literacy. An easy way to remember. This is that the early literacy test is the only one that does not have a state benchmark option on this screen. You can choose or change the subject selected and view all of your student scores. It is a good idea to check the record book for scores for all students who take the star benchmark before the benchmark window closes to make sure that their scores are showing without any error messages. If you click on a student's name in the record book, you will be taken to their individual testing history and you will be able to see all of the star tests that they have taken in that subject while they have been at Epic. If you have any questions, please reach out through fresh service to the instructional assessments team.

# %% [markdown]
# TOKENISE

# %%
import nltk
from nltk.corpus import words

raw_tokens = nltk.word_tokenize(merged_text)

print (raw_tokens)
# Out:
# ['To', 'access', 'your', 'star', 'reports', ',', 'you', 'will', 'click', 'on', 'the', 'reports', 'tile', 'on', 'your', 'Renaissance', 'home', 'page', 'and', 'then', 'star', 'assessment', '.', 'If', 'you', 'have', 'a', 'report', 'that', 'you', 'use', 'often', ',', 'you', 'can', 'click', 'the', 'thumb', 'tack', 'inside', 'that', 'report', 'tile', 'to', 'move', 'the', 'report', 'to', 'the', 'top', 'of', 'your', 'screen', '.', 'If', 'you', 'are', 'viewing', 'a', 'report', 'and', 'would', 'like', 'more', 'information', 'about', 'that', 'report', '.', 'Clicking', 'on', 'the', 'question', 'mark', 'at', 'the', 'top', 'of', 'your', 'screen', 'will', 'bring', 'up', 'an', 'article', 'from', 'Renaissance', 'that', 'explains', 'that', 'report', 'in', 'detail', '.', 'The', 'star', 'diagnostic', 'report', 'presents', 'diagnostic', 'and', 'skill', 'information', 'for', 'an', 'individual', 'student', '.', 'You', 'will', 'find', 'this', 'under', 'the', 'state', 'performance', 'and', 'mastery', 'section', 'of', 'your', 'reports', 'page', '.', 'When', 'choosing', 'your', 'reports', 'parameters', ',', 'there', 'are', 'two', 'things', 'you', 'want', 'to', 'keep', 'in', 'mind', 'always', 'select', 'the', 'benchmark', 'type', 'of', 'state', 'when', 'it', 'is', 'available', 'and', 'always', 'uncheck', 'the', 'show', 'grade', 'equivalent', 'box', 'as', 'that', 'can', 'be', 'confusing', 'for', 'students', 'and', 'parents', '.', 'This', 'report', 'has', 'a', 'color', 'coded', 'bar', 'that', 'will', 'show', 'you', 'where', 'your', 'student', 'is', 'performing', '.', 'The', 'report', 'will', 'also', 'show', 'you', 'your', 'students', 'scaled', 'score', '.', 'The', 'scaled', 'score', 'is', 'calculated', 'based', 'on', 'the', 'difficulty', 'of', 'questions', 'and', 'the', 'number', 'of', 'correct', 'responses', 'because', 'the', 'same', 'range', 'is', 'used', 'for', 'all', 'students', '.', 'Scaled', 'scores', 'can', 'be', 'used', 'to', 'compare', 'student', 'performance', 'across', 'grade', 'levels', '.', 'All', 'norm', 'reference', 'scores', 'are', 'derived', 'from', 'the', 'skilled', 'score', '.', 'The', 'percentile', 'rank', 'shows', 'you', 'where', 'your', 'students', 'scored', 'compared', 'to', 'other', 'students', 'that', 'took', 'the', 'test', 'in', 'the', 'same', 'grade', 'around', 'the', 'same', 'time', '.', 'The', 'instructional', 'reading', 'level', 'is', 'calculated', 'after', 'a', 'student', 'completes', 'a', 'star', 'reading', 'test', '.', 'It', 'is', 'a', 'criterion', 'reference', 'score', 'that', 'is', 'the', 'highest', 'reading', 'level', 'at', 'which', 'a', 'student', 'is', '80', '%', 'proficient', 'or', 'higher', 'at', 'comprehending', 'material', 'with', 'assistance', '.', 'Research', 'has', 'found', 'that', 'this', 'level', 'of', 'comprehension', 'corresponds', 'to', 'being', 'at', 'least', '90', 'to', '98', '%', 'proficient', 'at', 'recognizing', 'words', '.', 'Star', 'reading', 'does', 'not', 'directly', 'assess', 'word', 'recognition', 'and', 'instructional', 'reading', 'levels', 'are', 'pre', 'primer', 'primer', 'grades', 'one', 'through', '12.9', 'and', 'post', 'high', 'school', '.', 'The', 'diagnostic', 'test', 'also', 'shows', 'domain', 'scores', '.', 'It', "'ll", 'show', 'you', 'the', 'percent', 'of', 'mastery', 'on', 'skills', 'within', 'each', 'domain', 'in', 'the', 'student', "'s", 'grade', 'level', '.', 'You', 'can', 'also', 'see', 'the', 'zone', 'of', 'proximal', 'development', 'which', 'is', 'their', 'reading', 'level', 'and', 'it', 'has', 'a', 'link', 'to', 'a', 'book', 'finder', 'where', 'they', 'can', 'search', 'for', 'books', 'that', 'are', 'appropriate', 'for', 'them', 'in', 'their', 'ZPD', '.', 'You', 'can', 'also', 'see', 'their', 'test', 'duration', 'and', 'fidelity', 'located', 'in', 'this', 'report', '.', 'Today', ',', 'we', 'will', 'be', 'discussing', 'the', 'basics', 'of', 'giving', 'a', 'star', 'assessment', 'with', 'fidelity', 'set', 'clear', 'testing', 'expectations', 'with', 'your', 'students', 'and', 'famil ...

# %% [markdown]
# DELETE NOT WORDS (DATE, NUMBER, PUNCTUATION, ...)

# %%
import re

word_pattern = re.compile(r'^[^\W\d_]+$')  
words_tokens = [token for token in raw_tokens if word_pattern.match(token)]

print (words_tokens)
# Out:
# ['To', 'access', 'your', 'star', 'reports', 'you', 'will', 'click', 'on', 'the', 'reports', 'tile', 'on', 'your', 'Renaissance', 'home', 'page', 'and', 'then', 'star', 'assessment', 'If', 'you', 'have', 'a', 'report', 'that', 'you', 'use', 'often', 'you', 'can', 'click', 'the', 'thumb', 'tack', 'inside', 'that', 'report', 'tile', 'to', 'move', 'the', 'report', 'to', 'the', 'top', 'of', 'your', 'screen', 'If', 'you', 'are', 'viewing', 'a', 'report', 'and', 'would', 'like', 'more', 'information', 'about', 'that', 'report', 'Clicking', 'on', 'the', 'question', 'mark', 'at', 'the', 'top', 'of', 'your', 'screen', 'will', 'bring', 'up', 'an', 'article', 'from', 'Renaissance', 'that', 'explains', 'that', 'report', 'in', 'detail', 'The', 'star', 'diagnostic', 'report', 'presents', 'diagnostic', 'and', 'skill', 'information', 'for', 'an', 'individual', 'student', 'You', 'will', 'find', 'this', 'under', 'the', 'state', 'performance', 'and', 'mastery', 'section', 'of', 'your', 'reports', 'page', 'When', 'choosing', 'your', 'reports', 'parameters', 'there', 'are', 'two', 'things', 'you', 'want', 'to', 'keep', 'in', 'mind', 'always', 'select', 'the', 'benchmark', 'type', 'of', 'state', 'when', 'it', 'is', 'available', 'and', 'always', 'uncheck', 'the', 'show', 'grade', 'equivalent', 'box', 'as', 'that', 'can', 'be', 'confusing', 'for', 'students', 'and', 'parents', 'This', 'report', 'has', 'a', 'color', 'coded', 'bar', 'that', 'will', 'show', 'you', 'where', 'your', 'student', 'is', 'performing', 'The', 'report', 'will', 'also', 'show', 'you', 'your', 'students', 'scaled', 'score', 'The', 'scaled', 'score', 'is', 'calculated', 'based', 'on', 'the', 'difficulty', 'of', 'questions', 'and', 'the', 'number', 'of', 'correct', 'responses', 'because', 'the', 'same', 'range', 'is', 'used', 'for', 'all', 'students', 'Scaled', 'scores', 'can', 'be', 'used', 'to', 'compare', 'student', 'performance', 'across', 'grade', 'levels', 'All', 'norm', 'reference', 'scores', 'are', 'derived', 'from', 'the', 'skilled', 'score', 'The', 'percentile', 'rank', 'shows', 'you', 'where', 'your', 'students', 'scored', 'compared', 'to', 'other', 'students', 'that', 'took', 'the', 'test', 'in', 'the', 'same', 'grade', 'around', 'the', 'same', 'time', 'The', 'instructional', 'reading', 'level', 'is', 'calculated', 'after', 'a', 'student', 'completes', 'a', 'star', 'reading', 'test', 'It', 'is', 'a', 'criterion', 'reference', 'score', 'that', 'is', 'the', 'highest', 'reading', 'level', 'at', 'which', 'a', 'student', 'is', 'proficient', 'or', 'higher', 'at', 'comprehending', 'material', 'with', 'assistance', 'Research', 'has', 'found', 'that', 'this', 'level', 'of', 'comprehension', 'corresponds', 'to', 'being', 'at', 'least', 'to', 'proficient', 'at', 'recognizing', 'words', 'Star', 'reading', 'does', 'not', 'directly', 'assess', 'word', 'recognition', 'and', 'instructional', 'reading', 'levels', 'are', 'pre', 'primer', 'primer', 'grades', 'one', 'through', 'and', 'post', 'high', 'school', 'The', 'diagnostic', 'test', 'also', 'shows', 'domain', 'scores', 'It', 'show', 'you', 'the', 'percent', 'of', 'mastery', 'on', 'skills', 'within', 'each', 'domain', 'in', 'the', 'student', 'grade', 'level', 'You', 'can', 'also', 'see', 'the', 'zone', 'of', 'proximal', 'development', 'which', 'is', 'their', 'reading', 'level', 'and', 'it', 'has', 'a', 'link', 'to', 'a', 'book', 'finder', 'where', 'they', 'can', 'search', 'for', 'books', 'that', 'are', 'appropriate', 'for', 'them', 'in', 'their', 'ZPD', 'You', 'can', 'also', 'see', 'their', 'test', 'duration', 'and', 'fidelity', 'located', 'in', 'this', 'report', 'Today', 'we', 'will', 'be', 'discussing', 'the', 'basics', 'of', 'giving', 'a', 'star', 'assessment', 'with', 'fidelity', 'set', 'clear', 'testing', 'expectations', 'with', 'your', 'students', 'and', 'families', 'Before', 'testing', 'begins', 'it', 'is', 'important', 'to', 'give', 'the', 'a', 'test', 'in', 'a', 'quiet', 'distraction', 'free', 'environment', 'If', 'distractions' ...

# %% [markdown]
# NORMALISE

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

# Function to convert words to their base form (lemma)
def convert_to_base_form(words):
    lemmatizer = WordNetLemmatizer()
    # Tokenize the words and tag them with their part of speech
    tagged_words = nltk.pos_tag(words)
    # Lemmatize each word based on its part of speech
    base_form_words = []
    for word, pos_tag in tagged_words:
        wordnet_pos = get_wordnet_pos(pos_tag)
        word = word.lower()
        if wordnet_pos:
            base_form_words.append(lemmatizer.lemmatize(word, pos=wordnet_pos))
        else:
            base_form_words.append(word)  # If part of speech is not recognized, keep the word as is
    return base_form_words

# Function to map NLTK's POS tags to WordNet POS tags
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None  # Other parts of speech

normalized_tokens = convert_to_base_form(words_tokens)
print(normalized_tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['to', 'access', 'your', 'star', 'report', 'you', 'will', 'click', 'on', 'the', 'report', 'tile', 'on', 'your', 'renaissance', 'home', 'page', 'and', 'then', 'star', 'assessment', 'if', 'you', 'have', 'a', 'report', 'that', 'you', 'use', 'often', 'you', 'can', 'click', 'the', 'thumb', 'tack', 'inside', 'that', 'report', 'tile', 'to', 'move', 'the', 'report', 'to', 'the', 'top', 'of', 'your', 'screen', 'if', 'you', 'be', 'view', 'a', 'report', 'and', 'would', 'like', 'more', 'information', 'about', 'that', 'report', 'click', 'on', 'the', 'question', 'mark', 'at', 'the', 'top', 'of', 'your', 'screen', 'will', 'bring', 'up', 'an', 'article', 'from', 'renaissance', 'that', 'explain', 'that', 'report', 'in', 'detail', 'the', 'star', 'diagnostic', 'report', 'present', 'diagnostic', 'and', 'skill', 'information', 'for', 'an', 'individual', 'student', 'you', 'will', 'find', 'this', 'under', 'the', 'state', 'performance', 'and', 'mastery', 'section', 'of', 'your', 'report', 'page', 'when', 'choose', 'your', 'report', 'parameter', 'there', 'be', 'two', 'thing', 'you', 'want', 'to', 'keep', 'in', 'mind', 'always', 'select', 'the', 'benchmark', 'type', 'of', 'state', 'when', 'it', 'be', 'available', 'and', 'always', 'uncheck', 'the', 'show', 'grade', 'equivalent', 'box', 'as', 'that', 'can', 'be', 'confuse', 'for', 'student', 'and', 'parent', 'this', 'report', 'have', 'a', 'color', 'cod', 'bar', 'that', 'will', 'show', 'you', 'where', 'your', 'student', 'be', 'perform', 'the', 'report', 'will', 'also', 'show', 'you', 'your', 'student', 'scale', 'score', 'the', 'scale', 'score', 'be', 'calculate', 'base', 'on', 'the', 'difficulty', 'of', 'question', 'and', 'the', 'number', 'of', 'correct', 'response', 'because', 'the', 'same', 'range', 'be', 'use', 'for', 'all', 'student', 'scale', 'score', 'can', 'be', 'use', 'to', 'compare', 'student', 'performance', 'across', 'grade', 'level', 'all', 'norm', 'reference', 'score', 'be', 'derive', 'from', 'the', 'skilled', 'score', 'the', 'percentile', 'rank', 'show', 'you', 'where', 'your', 'student', 'score', 'compare', 'to', 'other', 'student', 'that', 'take', 'the', 'test', 'in', 'the', 'same', 'grade', 'around', 'the', 'same', 'time', 'the', 'instructional', 'reading', 'level', 'be', 'calculate', 'after', 'a', 'student', 'complete', 'a', 'star', 'read', 'test', 'it', 'be', 'a', 'criterion', 'reference', 'score', 'that', 'be', 'the', 'high', 'reading', 'level', 'at', 'which', 'a', 'student', 'be', 'proficient', 'or', 'high', 'at', 'comprehend', 'material', 'with', 'assistance', 'research', 'have', 'find', 'that', 'this', 'level', 'of', 'comprehension', 'corresponds', 'to', 'be', 'at', 'least', 'to', 'proficient', 'at', 'recognize', 'word', 'star', 'reading', 'do', 'not', 'directly', 'assess', 'word', 'recognition', 'and', 'instructional', 'reading', 'level', 'be', 'pre', 'primer', 'primer', 'grade', 'one', 'through', 'and', 'post', 'high', 'school', 'the', 'diagnostic', 'test', 'also', 'show', 'domain', 'score', 'it', 'show', 'you', 'the', 'percent', 'of', 'mastery', 'on', 'skill', 'within', 'each', 'domain', 'in', 'the', 'student', 'grade', 'level', 'you', 'can', 'also', 'see', 'the', 'zone', 'of', 'proximal', 'development', 'which', 'be', 'their', 'reading', 'level', 'and', 'it', 'have', 'a', 'link', 'to', 'a', 'book', 'finder', 'where', 'they', 'can', 'search', 'for', 'book', 'that', 'be', 'appropriate', 'for', 'them', 'in', 'their', 'zpd', 'you', 'can', 'also', 'see', 'their', 'test', 'duration', 'and', 'fidelity', 'locate', 'in', 'this', 'report', 'today', 'we', 'will', 'be', 'discuss', 'the', 'basic', 'of', 'give', 'a', 'star', 'assessment', 'with', 'fidelity', 'set', 'clear', 'test', 'expectation', 'with', 'your', 'student', 'and', 'family', 'before', 'test', 'begin', 'it', 'be', 'important', 'to', 'give', 'the', 'a', 'test', 'in', 'a', 'quiet', 'distraction', 'free', 'environment', 'if', 'distraction', 'arise', 'during', 'the', 'test', 'session', 'stop', 'the', 'test', 'and', 'reschedule', 'fo ...

# %% [markdown]
# DELETE A DUPLICATES

# %%
unique_tokens_set = set(normalized_tokens)
unique_tokens = list(unique_tokens_set)

print(unique_tokens)
# Out:
# ['shorten', 'false', 'amanda', 'virtually', 'loose', 'channel', 'diagram', 'browser', 'creation', 'candy', 'applies', 'wheel', 'air', 'rotation', 'management', 'together', 'featured', 'fix', 'overview', 'blogs', 'jump', 'solar', 'martian', 'feedback', 'discover', 'sight', 'dependent', 'confusing', 'when', 'worry', 'sake', 'typically', 'identification', 'sorting', 'leave', 'finally', 'algebra', 'checkpoint', 'reading', 'describe', 'there', 'winter', 'shall', 'sheet', 'calculate', 'grow', 'stanford', 'intro', 'triangle', 'component', 'hopefully', 'andreas', 'que', 'r', 'fear', 'eye', 'switch', 'kiddos', 'each', 'appreciate', 'particular', 'left', 'not', 'data', 'expressive', 'explanatory', 'browse', 'often', 'recreate', 'zpd', 'grasp', 'formative', 'testing', 'correctly', 'graphics', 'academic', 'warrant', 'before', 'gravitational', 'session', 'life', 'subtract', 'plug', 'string', 'practical', 'somewhat', 'tag', 'lizz', 'if', 'fully', 'boundary', 'branch', 'uncomfortable', 'without', 'collaboration', 'anyone', 'difference', 'amazon', 'source', 'so', 'notify', 'strand', 'recognize', 'lens', 'multiple', 'person', 'block', 'few', 'function', 'house', 'british', 'distracting', 'partnership', 'clickable', 'while', 'term', 'disable', 'similar', 'official', 'tend', 'five', 'opinion', 'beauty', 'everyday', 'article', 'silly', 'mathematical', 'brain', 'pie', 'simply', 'resonate', 'plus', 'disagree', 'quickly', 'interested', 'team', 'demand', 'through', 'phenomenon', 'disappear', 'caitlyn', 'loud', 'everything', 'plot', 'writing', 'saw', 'friend', 'remind', 'minute', 'babble', 'acquisition', 'station', 'administration', 'context', 'short', 'historical', 'full', 'sorry', 'overwrite', 'complement', 'applicable', 'takeaway', 'explanation', 'anytime', 'fun', 'windows', 'unpack', 'otherwise', 'count', 'principle', 'nepad', 'erica', 'percentile', 'permission', 'cbm', 'reschedule', 'pretty', 'gif', 'diagnosis', 'map', 'spread', 'also', 'visual', 'housekeeping', 'prerecords', 'pleasure', 'lunch', 'pressure', 'quick', 'different', 'currently', 'with', 'rejoice', 'nearly', 'reference', 'forward', 'dean', 'unstable', 'heavy', 'pronunciation', 'deborah', 'mountain', 'icann', 'culminate', 'have', 'db', 'statement', 'trip', 'pyramid', 'success', 'always', 'intend', 'mundane', 'broadly', 'dashboard', 'hyperlink', 'premade', 'inclination', 'grandfather', 'instruct', 'exist', 'mutation', 'washington', 'stick', 'patience', 'probation', 'hyper', 'everybody', 'question', 'extra', 'talk', 'average', 'light', 'supplemental', 'spreadsheet', 'original', 'pre', 'gamification', 'build', 'guidance', 'implodes', 'style', 'off', 'wonderful', 'overwhelm', 'adverb', 'b', 'rely', 'ability', 'co', 'nonsense', 'videos', 'near', 'yours', 'burn', 'community', 'exactly', 'delete', 'download', 'get', 'state', 'skills', 'fly', 'ay', 'clicking', 'straight', 'organize', 'technical', 'collection', 'amber', 'websites', 'essential', 'late', 'phrase', 'greeting', 'sh', 'promote', 'answer', 'instrumental', 'day', 'wife', 'much', 'prepare', 'chatbox', 'read', 'indication', 'learn', 'music', 'engagement', 'apply', 'percentage', 'neural', 'thompson', 'role', 'via', 'gradual', 'clothes', 'professionally', 'use', 'lose', 'foremost', 'rod', 'unchecked', 'send', 'young', 'jimenez', 'differently', 'high', 'prove', 'health', 'black', 'incorporate', 'dandy', 'excuse', 'derive', 'sufficiency', 'familiar', 'interest', 'ba', 'track', 'unknown', 'himself', 'exploration', 'allow', 'moving', 'again', 'firing', 'select', 'case', 'equitable', 'grader', 'drawl', 'character', 'te', 'dynamic', 'adult', 'update', 'assistance', 'design', 'md', 'clearly', 'reinvent', 'despair', 'other', 'convert', 'paste', 'changer', 'minus', 'certain', 'consultant', 'hook', 'literally', 'confidence', 'rip', 'fact', 'tiered', 'cold', 'regular', 'responses', 'political', 'overall', 'pardon', 'genetic', 'outcomes', 'blog', 'camera', 'exit', 'kaylyn', 'translate', 'remnant', 'rock', 'passion', 'desk', 'move', 'perfectly', 'bet ...

# %% [markdown]
# LIST OF INCORRECT WORDS

# %%
from nltk.corpus import words
nltk.download('words')


english_vocab = set(words.words())
strange_tokens = [word for word in unique_tokens if word not in english_vocab]

print(strange_tokens)
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# ['amanda', 'applies', 'blogs', 'martian', 'confusing', 'sorting', 'checkpoint', 'stanford', 'intro', 'andreas', 'que', 'kiddos', 'zpd', 'lizz', 'amazon', 'british', 'distracting', 'clickable', 'caitlyn', 'takeaway', 'anytime', 'windows', 'nepad', 'erica', 'cbm', 'prerecords', 'deborah', 'icann', 'db', 'hyperlink', 'premade', 'washington', 'spreadsheet', 'pre', 'gamification', 'implodes', 'co', 'videos', 'download', 'skills', 'clicking', 'websites', 'chatbox', 'thompson', 'jimenez', 'md', 'responses', 'outcomes', 'blog', 'kaylyn', 'bethany', 'diff', 'qual', 'mic', 'overtook', 'dennis', 'hype', 'powerpoints', 'chris', 'earned', 'checking', 'pairs', 'uploader', 'intertex', 'prete', 'christa', 'friends', 'melissa', 'plc', 'contextualizing', 'async', 'vr', 'columns', 'adding', 'updated', 'url', 'kimberly', 'tuesday', 'tanya', 'mikos', 'contextualize', 'nepo', 'caitlin', 'updating', 'odin', 'ron', 'jessica', 'cetera', 'rsars', 'lisa', 'worksheet', 'steelers', 'oops', 'krista', 'vocab', 'ic', 'ac', 'website', 'www', 'recommended', 'editorialism', 'tracy', 'personalized', 'gp', 'multi', 'nearer', 'becky', 'asynchronously', 'workarounds', 'portfoli', 'npa', 'greece', 'firmo', 'digi', 'devani', 'spotify', 'devanny', 'glitch', 'reporting', 'brainstorm', 'rpt', 'valerie', 'srpt', 'christia', 'attendee', 'mini', 'yay', 'emily', 'iep', 'nepa', 'backslash', 'spanish', 'qd', 'onedrive', 'alicia', 'timeline', 'suzanne', 'avatar', 'scott', 'sens', 'itunes', 'mom', 'oklahoma', 'cre', 'nd', 'keyword', 'com', 'google', 'baum', 'mics', 'oden', 'kepler', 'rachel', 'multisensory', 'smiley', 'restroom', 'sandra', 'classmates', 'carroll', 'stu', 'andrea', 'david', 'promo', 'reposted', 'coordinator', 'angela', 'courtney', 'voca', 'ii', 'keywords', 'ish', 'et', 'lindsay', 'marissa', 'subfolder', 'internet', 'rt', 'pd', 'portfolios', 'carolina', 'nilly', 'mx', 'embedded', 'andela', 'hyperlinked', 'napo', 'slideshow', 'pittsburgh', 'oz', 'playlist', 'started', 'kathy', 'online', 'ed', 'checklist', 'assessments', 'george', 'lacey', 'processing', 'mendy', 'julie', 'highlighter', 'uns', 'downloaded', 'angie', 'unmute', 'liz', 'shari', 'hang', 'catherine', 'lp', 'rs', 'corresponds', 'harris', 'powerpoint', 'giorgio', 'stairs', 'carissa', 'pr', 'benchmarks', 'airpod', 'pennsylvania', 'required', 'webinars', 'solving', 'answered', 'ops', 'app', 'earlier', 'ki', 'tp', 'individualized', 'chinese', 'upload', 'demonstrating', 'coordinate', 'november', 'keypad', 'oakies', 'verifies', 'benchmarking', 'facebook', 'demo', 'porn', 'mlk', 'rzkau', 'screenshot', 'checkmark', 'heard', 'sel', 'op', 'ok', 'mhm', 'instagram', 'sharing', 'georgio', 'workflow', 'toolbar', 'deeper', 'iowa', 'christy', 'screenshots', 'planning', 'chandra', 'anymore', 'michelle', 'webinar', 'laurie', 'uploaded', 'punit', 'questioning', 'frida', 'benchmark', 'uh', 'kid', 'database', 'gamified', 'assessing', 'birmingham', 'kaitlyn', 'medias', 'kaitlin', 'robert', 'clunky', 'misbehaving', 'names', 'll', 'english', 'typing', 'suggested', 'pqd', 'bm', 'inclined', 'monitoring', 'ch', 'hashtag', 'pearce', 'dropbox', 'functioning', 'ieps', 'alexandria', 'others', 'fo', 'hm', 'charlotte', 'rebecca', 'lets', 'bc', 'susan', 'offline', 'homepage', 'email', 'psyched', 'sarah', 'logo', 'customize', 'trina', 'strengths', 'manipulatives', 'karina', 'rhonda', 'dna', 'razzle', 'keillor', 'audrey', 'youtube', 'gina', 'jamie', 'suzie', 'editable', 'nerd', 'gifts', 'american', 'antonella', 'kahlo', 'adam', 'netflix', 'mm', 'joanne', 'ashley', 'cassandra', 'fab', 'october', 'pdf', 'meer']

# %% [markdown]
# DELETE NAMES, TOPONIMS AND ETC.

# %%
import nltk
from nltk.corpus import names

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('names')

# Function to delete common abbreviations and topynoms from a list of tokens
def delete_common_abbreviations_and_toponyms(tokens):
    # Load NLTK's names corpus
    names_corpus = set(name.lower() for name in names.words())
    # Tag tokens with parts of speech
    tagged_tokens = nltk.pos_tag(tokens)
    # Filter out tokens that are abbreviations, toponyms, or names
    filtered_tokens = [token for token, pos in tagged_tokens if pos != 'NNP' and pos != 'NNPS' and token.lower() not in names_corpus]
    return filtered_tokens

not_valuable_tokens = delete_common_abbreviations_and_toponyms(strange_tokens)
print(not_valuable_tokens)
# Out:
# ['applies', 'blogs', 'martian', 'confusing', 'sorting', 'checkpoint', 'intro', 'que', 'kiddos', 'zpd', 'lizz', 'amazon', 'british', 'distracting', 'clickable', 'caitlyn', 'takeaway', 'anytime', 'windows', 'nepad', 'cbm', 'prerecords', 'icann', 'db', 'hyperlink', 'premade', 'spreadsheet', 'pre', 'gamification', 'implodes', 'co', 'videos', 'download', 'skills', 'clicking', 'websites', 'chatbox', 'thompson', 'jimenez', 'md', 'responses', 'outcomes', 'blog', 'diff', 'qual', 'overtook', 'hype', 'powerpoints', 'earned', 'checking', 'pairs', 'uploader', 'intertex', 'prete', 'friends', 'plc', 'contextualizing', 'async', 'vr', 'columns', 'adding', 'updated', 'url', 'mikos', 'contextualize', 'nepo', 'updating', 'cetera', 'rsars', 'worksheet', 'steelers', 'oops', 'vocab', 'ic', 'ac', 'website', 'www', 'recommended', 'editorialism', 'personalized', 'gp', 'multi', 'nearer', 'asynchronously', 'workarounds', 'portfoli', 'npa', 'greece', 'firmo', 'digi', 'devani', 'spotify', 'devanny', 'glitch', 'reporting', 'brainstorm', 'rpt', 'srpt', 'christia', 'attendee', 'mini', 'yay', 'iep', 'nepa', 'backslash', 'spanish', 'qd', 'onedrive', 'timeline', 'avatar', 'sens', 'itunes', 'mom', 'oklahoma', 'cre', 'nd', 'keyword', 'com', 'google', 'baum', 'mics', 'oden', 'kepler', 'multisensory', 'smiley', 'restroom', 'classmates', 'promo', 'reposted', 'coordinator', 'voca', 'ii', 'keywords', 'ish', 'et', 'subfolder', 'internet', 'rt', 'pd', 'portfolios', 'nilly', 'mx', 'embedded', 'andela', 'hyperlinked', 'napo', 'slideshow', 'pittsburgh', 'oz', 'playlist', 'started', 'online', 'checklist', 'assessments', 'processing', 'mendy', 'highlighter', 'uns', 'downloaded', 'unmute', 'hang', 'lp', 'rs', 'corresponds', 'powerpoint', 'stairs', 'pr', 'benchmarks', 'airpod', 'pennsylvania', 'required', 'webinars', 'solving', 'answered', 'ops', 'app', 'earlier', 'tp', 'individualized', 'chinese', 'upload', 'demonstrating', 'coordinate', 'november', 'keypad', 'oakies', 'verifies', 'benchmarking', 'facebook', 'demo', 'porn', 'mlk', 'rzkau', 'screenshot', 'checkmark', 'heard', 'sel', 'op', 'ok', 'mhm', 'instagram', 'sharing', 'georgio', 'workflow', 'toolbar', 'deeper', 'iowa', 'screenshots', 'planning', 'anymore', 'webinar', 'uploaded', 'punit', 'questioning', 'frida', 'benchmark', 'uh', 'kid', 'database', 'gamified', 'assessing', 'birmingham', 'clunky', 'misbehaving', 'names', 'll', 'english', 'typing', 'suggested', 'pqd', 'bm', 'inclined', 'monitoring', 'ch', 'hashtag', 'dropbox', 'functioning', 'ieps', 'alexandria', 'others', 'fo', 'hm', 'lets', 'bc', 'offline', 'homepage', 'email', 'psyched', 'logo', 'customize', 'strengths', 'manipulatives', 'dna', 'razzle', 'keillor', 'youtube', 'editable', 'nerd', 'gifts', 'american', 'kahlo', 'netflix', 'mm', 'fab', 'pdf', 'meer']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!

# %% [markdown]
# CALCULATE THE SCORE

# %%
count_unique_tokens = len(unique_tokens)
count_not_valuable_tokens = len(not_valuable_tokens)
score = round (count_not_valuable_tokens / count_unique_tokens, 2)

print(score)
# Out:
# 0.11

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

# Download necessary resources
nltk.download('punkt')
nltk.download('wordnet')

# Function to normalize words in a list
def normalize_words(words):
    normalized_words = []
    lemmatizer = WordNetLemmatizer()
    stemmer = PorterStemmer()
    
    for word in words:
        # Convert to lowercase
        word = word.lower()
        lemma = lemmatizer.lemmatize(word)
        #stem = stemmer.stem(word)
        normalized_words.append((lemma))
    
    return normalized_words

normalized_tokens = normalize_words(words_tokens)
print(normalized_tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['to', 'access', 'your', 'star', 'report', 'you', 'will', 'click', 'on', 'the', 'report', 'tile', 'on', 'your', 'renaissance', 'home', 'page', 'and', 'then', 'star', 'assessment', 'if', 'you', 'have', 'a', 'report', 'that', 'you', 'use', 'often', 'you', 'can', 'click', 'the', 'thumb', 'tack', 'inside', 'that', 'report', 'tile', 'to', 'move', 'the', 'report', 'to', 'the', 'top', 'of', 'your', 'screen', 'if', 'you', 'are', 'viewing', 'a', 'report', 'and', 'would', 'like', 'more', 'information', 'about', 'that', 'report', 'clicking', 'on', 'the', 'question', 'mark', 'at', 'the', 'top', 'of', 'your', 'screen', 'will', 'bring', 'up', 'an', 'article', 'from', 'renaissance', 'that', 'explains', 'that', 'report', 'in', 'detail', 'the', 'star', 'diagnostic', 'report', 'present', 'diagnostic', 'and', 'skill', 'information', 'for', 'an', 'individual', 'student', 'you', 'will', 'find', 'this', 'under', 'the', 'state', 'performance', 'and', 'mastery', 'section', 'of', 'your', 'report', 'page', 'when', 'choosing', 'your', 'report', 'parameter', 'there', 'are', 'two', 'thing', 'you', 'want', 'to', 'keep', 'in', 'mind', 'always', 'select', 'the', 'benchmark', 'type', 'of', 'state', 'when', 'it', 'is', 'available', 'and', 'always', 'uncheck', 'the', 'show', 'grade', 'equivalent', 'box', 'a', 'that', 'can', 'be', 'confusing', 'for', 'student', 'and', 'parent', 'this', 'report', 'ha', 'a', 'color', 'coded', 'bar', 'that', 'will', 'show', 'you', 'where', 'your', 'student', 'is', 'performing', 'the', 'report', 'will', 'also', 'show', 'you', 'your', 'student', 'scaled', 'score', 'the', 'scaled', 'score', 'is', 'calculated', 'based', 'on', 'the', 'difficulty', 'of', 'question', 'and', 'the', 'number', 'of', 'correct', 'response', 'because', 'the', 'same', 'range', 'is', 'used', 'for', 'all', 'student', 'scaled', 'score', 'can', 'be', 'used', 'to', 'compare', 'student', 'performance', 'across', 'grade', 'level', 'all', 'norm', 'reference', 'score', 'are', 'derived', 'from', 'the', 'skilled', 'score', 'the', 'percentile', 'rank', 'show', 'you', 'where', 'your', 'student', 'scored', 'compared', 'to', 'other', 'student', 'that', 'took', 'the', 'test', 'in', 'the', 'same', 'grade', 'around', 'the', 'same', 'time', 'the', 'instructional', 'reading', 'level', 'is', 'calculated', 'after', 'a', 'student', 'completes', 'a', 'star', 'reading', 'test', 'it', 'is', 'a', 'criterion', 'reference', 'score', 'that', 'is', 'the', 'highest', 'reading', 'level', 'at', 'which', 'a', 'student', 'is', 'proficient', 'or', 'higher', 'at', 'comprehending', 'material', 'with', 'assistance', 'research', 'ha', 'found', 'that', 'this', 'level', 'of', 'comprehension', 'corresponds', 'to', 'being', 'at', 'least', 'to', 'proficient', 'at', 'recognizing', 'word', 'star', 'reading', 'doe', 'not', 'directly', 'ass', 'word', 'recognition', 'and', 'instructional', 'reading', 'level', 'are', 'pre', 'primer', 'primer', 'grade', 'one', 'through', 'and', 'post', 'high', 'school', 'the', 'diagnostic', 'test', 'also', 'show', 'domain', 'score', 'it', 'show', 'you', 'the', 'percent', 'of', 'mastery', 'on', 'skill', 'within', 'each', 'domain', 'in', 'the', 'student', 'grade', 'level', 'you', 'can', 'also', 'see', 'the', 'zone', 'of', 'proximal', 'development', 'which', 'is', 'their', 'reading', 'level', 'and', 'it', 'ha', 'a', 'link', 'to', 'a', 'book', 'finder', 'where', 'they', 'can', 'search', 'for', 'book', 'that', 'are', 'appropriate', 'for', 'them', 'in', 'their', 'zpd', 'you', 'can', 'also', 'see', 'their', 'test', 'duration', 'and', 'fidelity', 'located', 'in', 'this', 'report', 'today', 'we', 'will', 'be', 'discussing', 'the', 'basic', 'of', 'giving', 'a', 'star', 'assessment', 'with', 'fidelity', 'set', 'clear', 'testing', 'expectation', 'with', 'your', 'student', 'and', 'family', 'before', 'testing', 'begin', 'it', 'is', 'important', 'to', 'give', 'the', 'a', 'test', 'in', 'a', 'quiet', 'distraction', 'free', 'environment', 'if', 'distraction', 'arise', 'during', 'the', 'testing', 's ...
